# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('hotel_booking.csv')

# %% [markdown]
# ## Data Cleaning

# %%
data.sample(3)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 53121   City Hotel            1          0               2016
# 109757  City Hotel            0          4               2017
# 45741   City Hotel            0         98               2015
#
#        arrival_date_month  arrival_date_week_number  \
# 53121                June                        25
# 109757              April                        15
# 45741            November                        48
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 53121                          16                        0
# 109757                         10                        2
# 45741                          23                        1
#
#         stays_in_week_nights  adults  ...    customer_type     adr  \
# 53121                      1       2  ...        Transient    0.00
# 109757                     5       2  ...        Transient  154.29
# ...

# %%
data.shape
# Out:
# (119390, 36)

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %% [markdown]
# Removing the customers Persomal data from the data set. These data are as follows
# - Name
# - Email
# - Phone Number
# - Credit card

# %%
data.drop(columns=['name', 'email', 'phone-number', 'credit_card'],  inplace= True)
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# Checking the types of the data and converting it to the required format

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
data['reservation_status_date'] = pd.to_datetime(data.reservation_status_date)
data.head()

print(data.reservation_status_date[0])
type(data.reservation_status_date[0])
# Out:
# 2015-07-01 00:00:00
# pandas._libs.tslibs.timestamps.Timestamp

# %%
data.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %% [markdown]
# Checking the different unique values for each of the columns

# %%
for col in data.describe(include='object').columns:
    print(col)
    print(data[col].unique())
    print('-'*100)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ----------------------------------------------------------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ----------------------------------------------------------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ----------------------------------------------------------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
# ...

# %% [markdown]
# Now Dropping differnt columns form the data.
# - agent, company -> Too many missing records to handle and no use as of now
#
# Removing data rows with missing values
# - Removing columns missing country(488) and Childern(4)

# %%
# Data shape before removing the null values
data.shape
# Out:
# (119390, 32)

# %%
data.drop(columns=['agent', 'company'],inplace=True)
data.dropna(inplace=True)
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
# Data shape after removing the null values
data.shape
# Out:
# (118898, 30)

# %%
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# Removing some of the outliars

# %%
num_cols = list(data.describe().columns)
num_cols.pop()
len(num_cols)
# Out:
# 18

# %%
plt.figure(figsize=(20,20))
for i in range(len(num_cols)) :
    plt.subplot(len(num_cols)//5 +1 ,5,i+1)
    plt.boxplot(data[num_cols[i]])
    plt.title(f"{i+1}. {num_cols[i]}")
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Few data points treatd as Outliares form the data
#
# - lead time > 650
# - stays in weekend night > 10
# - staus in week nights > 30
# - children = 10
# - babies > 7
# - adr > 1000
# - required Car parking > 4

# %%
data = data[data.lead_time < 650]
data = data[data.stays_in_weekend_nights < 10]
data = data[data.stays_in_week_nights < 30]
data = data[data.children < 10]
data = data[data.babies < 7]
data = data[data.adr < 1000]

data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
# 5                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
data.shape
# Out:
# (118872, 30)

# %%
plt.figure(figsize=(20,20))
for i in range(len(num_cols)) :
    plt.subplot(len(num_cols)//5 +1 ,5,i+1)
    plt.boxplot(data[num_cols[i]])
    plt.title(f"{i+1}. {num_cols[i]}")
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Other's logical outliars can be removed which I am skipping as of now
# This can be situational or anything.<br>
# Like Number of cars > Number of adults

# %%
data[data.required_car_parking_spaces > data.adults]
# More of this kind of data can be removed
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 14039   Resort Hotel            0         74               2017
# 16656   Resort Hotel            0        199               2015
# 29045   Resort Hotel            0         26               2017
# 29046   Resort Hotel            0        138               2017
# 31765   Resort Hotel            0         31               2016
# 38117   Resort Hotel            0        205               2017
# 85931     City Hotel            0          9               2016
# 86799     City Hotel            0          0               2016
# 92962     City Hotel            0         55               2017
# 101957    City Hotel            0         37               2016
# 102762    City Hotel            0         13               2016
# 104879    City Hotel            0         16               2017
# 107977    City Hotel            0          0               2017
# 110812    City Hotel            0         30               2017
# ...

# %% [markdown]
# # Analysis and Visualizations

# %%
cancellation_perc = data.is_canceled.value_counts(normalize=True) * 100
# By normalizing it returns Percentage

cancellation_perc

# Creating plot for easy visualization
plt.figure(figsize=(4,3))
plt.title("Reservation status")
plt.bar(['Not Cancelled', 'Cancelled'],data.is_canceled.value_counts(), width= .6)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# Creating count plot to see the distribution of the cancellaion

# %%
plt.figure(figsize=(6,4))
ax1 = sns.countplot(x = 'hotel', hue = 'is_canceled', data=data, palette='Blues')
# lagendLables, _ = ax1.get_legend_handles_labels()
# ax1.legend(box_to_anchor(1,1))

plt.title('Reservation status hotel wise', size = 12)
plt.xlabel('Hotel')
plt.ylabel('Number of Hotels')
plt.legend(['Not Cancelled', 'Cancelled'])

# %%
resHot = data[data.hotel == 'Resort Hotel']
resHot.is_canceled.value_counts(normalize=True)*100
# Out:
# is_canceled
# 0    72.020516
# 1    27.979484
# Name: proportion, dtype: float64

# %%
ctyHotel = data[data.hotel == 'City Hotel']
ctyHotel.is_canceled.value_counts(normalize=True)*100
# Out:
# is_canceled
# 0    58.290139
# 1    41.709861
# Name: proportion, dtype: float64

# %% [markdown]
# Roughly 42% of the city Hotels are getting cancelled

# %% [markdown]
# Checking the effect of average daily price in the cancellation

# %%
resHot = resHot.groupby('reservation_status_date')[['adr']].mean()
ctyHotel = ctyHotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(10,5))
plt.plot(resHot.index, resHot.adr, c = '#00F', label = 'Resort Hotel')
plt.plot(ctyHotel.index, ctyHotel.adr, c = '#88F', label = 'City Hotel')
plt.title('Average daily rate')
plt.legend()
plt.xlabel('days')
plt.ylabel('Prices')
# Out:
# Text(0, 0.5, 'Prices')

# %% [markdown]
# Now we are going to take a look at how is the trend of cancellation along the months

# %%
data['month']= data['reservation_status_date'].dt.month
plt.figure(figsize=(8,6))
ax1 = sns.countplot(x= 'month', hue='is_canceled', data = data)
plt.legend(['Not Canceled', 'canceled'])
plt.title('Hotel cancellation along Months')
# Out:
# Text(0.5, 1.0, 'Hotel cancellation along Months')

# %% [markdown]
# Now Checking the Effect of price in the cancellation to see the effect
#
# Below we are only taking the data where cancelaion is done, Grouping it by month and taking the mean of the prices..

# %%
canceled_data = data[data['is_canceled'] == 1]
tempDF = canceled_data.groupby('month')[['adr']].mean()
tempDF
plt.figure(figsize=(8,6))
plt.title('Adr per Month with cancelation')
sns.barplot(x='month',y='adr',data=tempDF)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Checking the cancellation with Country

# %%
top_countries = canceled_data['country'].value_counts()[:10]
top_countries
plt.figure(figsize=(7,7))
plt.title('Top Countries with cancellation')
plt.pie(top_countries, autopct='%.2f', labels=top_countries.index)
plt.show()

# %% [markdown]
# There are most cancellation seen in PORTUGAL, need to focus main on Prtugal in increasing the facilites and stuffs. Can run campagine or do any ohter thing s

# %%
data.market_segment.value_counts()
# Out:
# market_segment
# Online TA        56394
# Offline TA/TO    24149
# Groups           19805
# Direct           12444
# Corporate         5109
# Complementary      734
# Aviation           237
# Name: count, dtype: int64

# %%
data.market_segment.value_counts(normalize=True)*100
# Out:
# market_segment
# Online TA        47.440945
# Offline TA/TO    20.315129
# Groups           16.660778
# Direct           10.468403
# Corporate         4.297900
# Complementary     0.617471
# Aviation          0.199374
# Name: proportion, dtype: float64

# %%
canceled_data.market_segment.value_counts()
# Out:
# market_segment
# Online TA        20736
# Groups           12097
# Offline TA/TO     8274
# Direct            1920
# Corporate          978
# Complementary       90
# Aviation            52
# Name: count, dtype: int64

# %%
canceled_data.market_segment.value_counts(normalize=True)*100
# Out:
# market_segment
# Online TA        46.970349
# Groups           27.401635
# Offline TA/TO    18.741930
# Direct            4.349106
# Corporate         2.215326
# Complementary     0.203864
# Aviation          0.117788
# Name: proportion, dtype: float64

# %%
cancel_adr = canceled_data.groupby('reservation_status_date')[['adr']].mean().reset_index()
cancel_adr['reservation_status_date'] = pd.to_datetime(cancel_adr['reservation_status_date'])
cancel_adr.sort_values('reservation_status_date', inplace=True)
cancel_adr
# Out:
#     reservation_status_date         adr
# 0                2014-10-17   62.800000
# 1                2014-11-18    0.000000
# 2                2015-01-01   62.062779
# 3                2015-01-02    9.633750
# 4                2015-01-18    0.000000
# ..                      ...         ...
# 897              2017-08-26  178.200000
# 898              2017-08-27  167.300000
# 899              2017-08-28   81.416667
# 900              2017-08-29  144.253333
# 901              2017-08-31  189.750000
#
# [902 rows x 2 columns]

# %%
not_canceled_data = data[data['is_canceled']==0]
not_cancel_adr = not_canceled_data.groupby('reservation_status_date')[['adr']].mean().reset_index()
not_cancel_adr.sort_values('reservation_status_date', inplace=True)
not_cancel_adr
# Out:
#     reservation_status_date         adr
# 0                2015-07-01   47.475000
# 1                2015-07-02   95.924000
# 2                2015-07-03   97.645205
# 3                2015-07-04  110.480000
# 4                2015-07-05  100.308485
# ..                      ...         ...
# 800              2017-09-08  101.012500
# 801              2017-09-09  147.778333
# 802              2017-09-10  145.272500
# 803              2017-09-12  153.570000
# 804              2017-09-14  105.930000
#
# [805 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
plt.plot(not_cancel_adr.reservation_status_date, not_cancel_adr.adr, label= 'Not Cancelled', c= '#A11')
plt.plot(cancel_adr.reservation_status_date, cancel_adr.adr, label= 'Cancelled', c='#B88')
plt.legend()
plt.title('Average daily Rate')
# Out:
# Text(0.5, 1.0, 'Average daily Rate')
